# %% [markdown]
# # Mask R-CNN - Apply model to hail imagery subsets
#
# Code and visualizations to test, debug, and evaluate the Mask R-CNN model.

# %%
import glob
import os
import sys
import random
import math
import re
import time
import json
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import skimage

from multiprocessing import Pool

# Root directory of the project
ROOT_DIR = os.path.abspath("/g/data1a/kl02/jss548/Mask_RCNN")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log

from samples.hail import hail

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = "/g/data1a/kl02/jss548/HailPixel/mask-rcnn"

#path to weights
HAIL_WEIGHTS_PATH = "/g/data1a/kl02/jss548/HailPixel/mask-rcnn/mask_rcnn_hail_final.h5"  # TODO: update this path

#path to subset images
SUBSET_PATH = '/g/data1a/kl02/jss548/HailPixel/subsets/images'
ROI_PATH    = '/g/data1a/kl02/jss548/HailPixel/subsets/roi'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Configurations

# %%
config = hail.HailConfig()
HAIL_DIR = os.path.join(ROOT_DIR, "datasets/hail")

# %%
# Override the training configurations with a few
# changes for inferencing.
class InferenceConfig(config.__class__):
    # Run detection on one image at a time
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        150
# DETECTION_MIN_CONFIDENCE       0.5
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           hail
# NUMBER_OF_EPOCHS               35
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                150
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Notebook Preferences

# %%
# Device to load the neural network on.
# Useful if you're training a model on the same 
# machine, in which case use CPU and leave the
# GPU for training.
DEVICE = "/cpu:0"  # /cpu:0 or /gpu:0

# Inspect the model in training or inference modes
# values: 'inference' or 'training'
# TODO: code for 'training' test mode not ready yet
TEST_MODE = "inference"

# %%
def get_ax(rows=1, cols=1, size=16):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Adjust the size attribute to control how big to render images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# ## Load Model

# %%
# Create model in inference mode
with tf.device(DEVICE):
    model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR,
                              config=config)
# Out:
# WARNING:tensorflow:From /g/data/en0/jss548/miniconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/sparse_ops.py:1165: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.

# %%
weights_path = HAIL_WEIGHTS_PATH #model.find_last()

# Load weights
print("Loading weights ", weights_path)
model.load_weights(weights_path, by_name=True)
# Out:
# Loading weights  /g/data1a/kl02/jss548/HailPixel_imagery/mask-rcnn/mask_rcnn_hail_final.h5

# %%
def chunks(l, n):
    """
    Yield successive n-sized chunks from l.
    From http://stackoverflow.com/a/312464
    """
    for i in range(0, len(l), n):
        yield l[i:i + n]

def process_image(subset_ffn):
    #read image
    image = skimage.io.imread(subset_ffn)
    #run model on image
    results  = model.detect([image], verbose=0)
    roi_list = results[0]['rois']
    #save back to file
    base = os.path.basename(subset_ffn)
    json_header = base + str(file_sz)
    #generate json header
    json_out = {json_header: {'filename': base,
                   'size': file_sz,
                   'regions':[],
                   'file_attributes':{}
                  }
                }
    #build json for every roi
    for roi in roi_list:
        #convert roi box to centroids
        cx = int((roi[1] + roi[3])/2)
        cy = int((roi[0] + roi[2])/2)
        #generate object for json
        json_out[json_header]['regions'].append({'shape_attributes':{'name':'point',
                                                        'cx': cx,
                                                        'cy': cy},
                                    'region_attributes':{}})
    #build json fn
    out_fn  = base[:-3] + 'json'
    out_ffn = '/'.join([ROI_PATH, out_fn])
    #write to file
    with open(out_ffn, 'w') as fp:
        json.dump(json_out, fp)
    #output to user
    print('finished', base, 'with number of detections', len(roi_list))

# %%
#list subsets
subset_ffn_list = sorted(glob.glob(SUBSET_PATH + '/*.png'))

for subset_ffn in subset_ffn_list:
    file_sz = os.path.getsize(subset_ffn)
    #check file size
    if file_sz/1000 < 50:
        continue
    #check index number
    base = os.path.basename(subset_ffn)
    base_index = int(base[:-4])
    if base_index<1128:
        continue
    process_image(subset_ffn) #last 1706


print('Finished')
# Out:
# finished 1128.png with number of detections 132
# finished 1129.png with number of detections 150
# finished 1130.png with number of detections 123
# finished 1131.png with number of detections 87
# finished 1132.png with number of detections 66
# finished 1133.png with number of detections 76
# finished 1134.png with number of detections 89
# finished 1135.png with number of detections 127
# finished 1136.png with number of detections 150
# finished 1137.png with number of detections 140
# finished 1138.png with number of detections 150
# finished 1139.png with number of detections 108
# finished 1140.png with number of detections 133
# finished 1141.png with number of detections 105
# finished 1142.png with number of detections 138
# finished 1143.png with number of detections 150
# finished 1144.png with number of detections 124
# finished 1145.png with number of detections 108
# finished 1146.png with number of detections 86
# finished 1147.png with number of detections 105
# finished 1148.png with number of detections 61
# finished 1149.png with number of detections 33
# finished 1150.png with number of detections 23
# finished 1151.png with number of detections 5
# finished 1169.png with number of detections 71
# finished 1170.png with number of detections 104
# finished 1171.png with number of detections 49
# finished 1172.png with number of detections 95
# finished 1173.png with number of detections 96
# finished 1174.png with number of detections 113
# finished 1175.png with number of detections 99
# finished 1176.png with number of detections 77
# finished 1177.png with number of detections 97
# finished 1178.png with number of detections 107
# finished 1179.png with number of detections 94
# finished 1180.png with number of detections 110
# finished 1181.png with number of detections 136
# finished 1182.png with number of detections 127
# finished 1183.png with number of detections 107
# finished 1184.png with number of detections 91
# finished 1185.png with number of detections 60
# finished 1186.png with number of detections 82
# finished 1187.png with number of detections 115
# finished 1188.png with number of detections 139
# finished 1189.png with number of detections 150
# finished 1190.png with number of detections 131
# finished 1191.png with number of detections 150
# finished 1192.png with number of detections 150
# finished 1193.png with number of detections 150
# finished 1194.png with number of detections 128
# finished 1195.png with number of detections 104
# finished 1196.png with number of detections 87
# finished 1197.png with number of detections 84
# finished 1198.png with number of detections 84
# finished 1199.png with number of detections 79
# finished 1200.png with number of detections 29
# finished 1201.png with number of detections 14
# finished 1222.png with number of detections 73
# finished 1223.png with number of detections 122
# finished 1224.png with number of detections 108
# finished 1225.png with number of detections 79
# finished 1226.png with number of detections 106
# finished 1227.png with number of detections 143
# finished 1228.png with number of detections 114
# finished 1229.png with number of detections 98
# finished 1230.png with number of detections 100
# finished 1231.png with number of detections 108
# finished 1232.png with number of detections 105
# finished 1233.png with number of detections 103
# finished 1234.png with number of detections 117
# finished 1235.png with number of detections 52
# finished 1236.png with number of detections 53
# finished 1237.png with number of detections 67
# finished 1238.png with number of detections 111
# finished 1239.png with number of detections 150
# finished 1240.png with number of detections 150
# finished 1241.png with number of detections 128
# finished 1242.png with number of detections 150
# finished 1243.png with number of detections 150
# finished 1244.png with number of detections 150
# finished 1245.png with number of detections 119
# finished 1246.png with number of detections 66
# finished 1247.png with number of detections 68
# finished 1248.png with number of detections 52
# finished 1249.png with number of detections 56
# finished 1250.png with number of detections 52
# finished 1251.png with number of detections 20
# finished 1275.png with number of detections 32
# finished 1276.png with number of detections 126
# finished 1277.png with number of detections 111
# finished 1278.png with number of detections 125
# finished 1279.png with number of detections 114
# finished 1280.png with number of detections 116
# finished 1281.png with number of detections 113
# finished 1282.png with number of detections 99
# finished 1283.png with number of detections 110
# finished 1284.png with number of detections 127
# finished 1285.png with number of detections 136
# finished 1286.png with number of detections 91
# finished 1287.png with number of detections 52
# finished 1288.png with number of detections 71
# finished 1289.png with number of detections 72
# finished 1290.png with number of detections 128
# finished 1291.png with number of detections 150
# finished 1292.png with number of detections 150
# finished 1293.png with number of detections 150
# finished 1294.png with number of detections 150
# finished 1295.png with number of detections 145
# finished 1296.png with number of detections 95
# finished 1297.png with number of detections 67
# finished 1298.png with number of detections 11
# finished 1299.png with number of detections 32
# finished 1300.png with number of detections 46
# finished 1301.png with number of detections 22
# finished 1302.png with number of detections 26
# finished 1329.png with number of detections 48
# finished 1330.png with number of detections 138
# finished 1331.png with number of detections 150
# finished 1332.png with number of detections 133
# finished 1333.png with number of detections 106
# finished 1334.png with number of detections 129
# finished 1335.png with number of detections 150
# finished 1336.png with number of detections 122
# finished 1337.png with number of detections 76
# finished 1338.png with number of detections 62
# finished 1339.png with number of detections 77
# finished 1340.png with number of detections 92
# finished 1341.png with number of detections 140
# finished 1342.png with number of detections 128
# finished 1343.png with number of detections 150
# finished 1344.png with number of detections 149
# finished 1345.png with number of detections 150
# finished 1346.png with number of detections 150
# finished 1347.png with number of detections 70
# finished 1348.png with number of detections 22
# finished 1349.png with number of detections 19
# finished 1350.png with number of detections 28
# finished 1351.png with number of detections 9
# finished 1352.png with number of detections 4
# finished 1353.png with number of detections 7
# finished 1354.png with number of detections 0
# finished 1383.png with number of detections 75
# finished 1384.png with number of detections 129
# finished 1385.png with number of detections 126
# finished 1386.png with number of detections 115
# finished 1387.png with number of detections 96
# finished 1388.png with number of detections 111
# finished 1389.png with number of detections 121
# finished 1390.png with number of detections 97
# finished 1391.png with number of detections 126
# finished 1392.png with number of detections 113
# finished 1393.png with number of detections 150
# finished 1394.png with number of detections 150
# finished 1395.png with number of detections 150
# finished 1396.png with number of detections 113
# finished 1397.png with number of detections 94
# finished 1398.png with number of detections 56
# finished 1399.png with number of detections 60
# finished 1400.png with number of detections 31
# finished 1401.png with number of detections 4
# finished 1402.png with number of detections 8
# finished 1403.png with number of detections 6
# finished 1404.png with number of detections 3
# finished 1437.png with number of detections 70
# finished 1438.png with number of detections 91
# finished 1439.png with number of detections 90
# finished 1440.png with number of detections 108
# finished 1441.png with number of detections 137
# finished 1442.png with number of detections 123
# finished 1443.png with number of detections 135
# finished 1444.png with number of detections 150
# finished 1445.png with number of detections 150
# finished 1446.png with number of detections 150
# finished 1447.png with number of detections 136
# finished 1448.png with number of detections 98
# finished 1449.png with number of detections 47
# finished 1450.png with number of detections 42
# finished 1451.png with number of detections 34
# finished 1452.png with number of detections 32
# finished 1453.png with number of detections 17
# finished 1454.png with number of detections 1
# finished 1455.png with number of detections 1
# finished 1490.png with number of detections 13
# finished 1491.png with number of detections 78
# finished 1492.png with number of detections 79
# finished 1493.png with number of detections 114
# finished 1494.png with number of detections 126
# finished 1495.png with number of detections 150
# finished 1496.png with number of detections 121
# finished 1497.png with number of detections 90
# finished 1498.png with number of detections 122
# finished 1499.png with number of detections 105
# finished 1500.png with number of detections 36
# finished 1501.png with number of detections 17
# finished 1502.png with number of detections 13
# finished 1503.png with number of detections 33
# finished 1504.png with number of detections 41
# finished 1505.png with number of detections 9
# finished 1506.png with number of detections 2
# finished 1544.png with number of detections 58
# finished 1545.png with number of detections 131
# finished 1546.png with number of detections 131
# finished 1547.png with number of detections 111
# finished 1548.png with number of detections 101
# finished 1549.png with number of detections 56
# finished 1550.png with number of detections 20
# finished 1551.png with number of detections 37
# finished 1552.png with number of detections 22
# finished 1553.png with number of detections 23
# finished 1554.png with number of detections 14
# finished 1555.png with number of detections 7
# finished 1556.png with number of detections 4
# finished 1597.png with number of detections 16
# finished 1598.png with number of detections 99
# finished 1599.png with number of detections 88
# finished 1600.png with number of detections 87
# finished 1601.png with number of detections 12
# finished 1602.png with number of detections 11
# finished 1603.png with number of detections 8
# finished 1604.png with number of detections 13
# finished 1605.png with number of detections 6
# finished 1651.png with number of detections 30
# finished 1652.png with number of detections 62
# finished 1653.png with number of detections 23
# finished 1654.png with number of detections 4
# finished 1655.png with number of detections 4
# finished 1704.png with number of detections 2
# finished 1705.png with number of detections 26
# finished 1706.png with number of detections 7
# Finished
